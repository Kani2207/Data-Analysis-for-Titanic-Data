# %%
from tkinter import *
root = Tk()
root.title("Creater window")

def Img():
    r = Toplevel()
    r.title("My image")

    canvas = Canvas(r, height=600, width=600)
    canvas.pack()
    my_image = PhotoImage(file='1.gif', master= root)
    canvas.create_image(0, 0, anchor=NW, image=my_image)
    r.mainloop()
    
def Img1():
    r = Toplevel()
    r.title("My image")

    canvas = Canvas(r, height=600, width=600)
    canvas.pack()
    my_image = PhotoImage(file='2.gif', master= root)
    canvas.create_image(0, 0, anchor=NW, image=my_image)
    r.mainloop()
    
def Img2():
    r = Toplevel()
    r.title("My image")

    canvas = Canvas(r, height=600, width=600)
    canvas.pack()
    my_image = PhotoImage(file='3.gif', master= root)
    canvas.create_image(0, 0, anchor=NW, image=my_image)
    r.mainloop()
    
def Img3():
    r = Toplevel()
    r.title("My image")

    canvas = Canvas(r, height=600, width=600)
    canvas.pack()
    my_image = PhotoImage(file='4.gif', master= root)
    canvas.create_image(0, 0, anchor=NW, image=my_image)
    r.mainloop()
    
def Img4():
    r = Toplevel()
    r.title("My image")

    canvas = Canvas(r, height=600, width=600)
    canvas.pack()
    my_image = PhotoImage(file='5.gif', master= root)
    canvas.create_image(0, 0, anchor=NW, image=my_image)
    r.mainloop()
    
def Img5():
    r = Toplevel()
    r.title("My image")

    canvas = Canvas(r, height=600, width=600)
    canvas.pack()
    my_image = PhotoImage(file='6.gif', master= root)
    canvas.create_image(0, 0, anchor=NW, image=my_image)
    r.mainloop()

def Img6():
    r = Toplevel()
    r.title("My image")

    canvas = Canvas(r, height=600, width=600)
    canvas.pack()
    my_image = PhotoImage(file='7.gif', master= root)
    canvas.create_image(0, 0, anchor=NW, image=my_image)
    r.mainloop()
    
def Img7():
    r = Toplevel()
    r.title("My image")

    canvas = Canvas(r, height=600, width=600)
    canvas.pack()
    my_image = PhotoImage(file='10.gif', master= root)
    canvas.create_image(0, 0, anchor=NW, image=my_image)
    r.mainloop()
    
def Img8():
    r = Toplevel()
    r.title("My image")

    canvas = Canvas(r, height=600, width=600)
    canvas.pack()
    my_image = PhotoImage(file='11.gif', master= root)
    canvas.create_image(0, 0, anchor=NW, image=my_image)
    r.mainloop()

def Img9():
    r = Toplevel()
    r.title("My image")

    canvas = Canvas(r, height=600, width=600)
    canvas.pack()
    my_image = PhotoImage(file='12.gif', master= root)
    canvas.create_image(0, 0, anchor=NW, image=my_image)
    r.mainloop()
    
def Img10():
    r = Toplevel()
    r.title("My image")

    canvas = Canvas(r, height=600, width=600)
    canvas.pack()
    my_image = PhotoImage(file='13.gif', master= root)
    canvas.create_image(0, 0, anchor=NW, image=my_image)
    r.mainloop()
    
def Img11():
    r = Toplevel()
    r.title("My image")

    canvas = Canvas(r, height=600, width=600)
    canvas.pack()
    my_image = PhotoImage(file='14.gif', master= root)
    canvas.create_image(0, 0, anchor=NW, image=my_image)
    r.mainloop()
    
btn = Button(root, text = "Total number of passengers", command = Img)
btn.grid(row = 0, column = 0)

btn = Button(root, text = "dead vs survived passengers", command = Img1)
btn.grid(row = 1, column = 0)

btn = Button(root, text = "Survival Rate based on Gender", command = Img2)
btn.grid(row = 2, column = 0)

btn = Button(root, text = "Class-wise count of passengers", command = Img3)
btn.grid(row = 3, column = 0)

btn = Button(root, text = "Survival Rate based on Class", command = Img4)
btn.grid(row = 4, column = 0)

btn = Button(root, text = "Class-wise and gender-based count of passengers", command = Img5)
btn.grid(row = 5, column = 0)

btn = Button(root, text = "Class-wise and gender-based count of survived passengers", command = Img6)
btn.grid(row = 6, column = 0)

btn = Button(root, text = "Box Plot of age of passengers", command = Img7)
btn.grid(row = 7, column = 0)

btn = Button(root, text = "passengers age distribution", command = Img8)
btn.grid(row = 8, column = 0)

btn = Button(root, text = "Survival based on age of passengers", command = Img9)
btn.grid(row = 9, column = 0)


btn = Button(root, text = "Distribution on the basis of embarkment", command = Img10)
btn.grid(row = 10, column = 0)

btn = Button(root, text = "Class-wise Distribution on the basis of embarkment", command = Img11)
btn.grid(row = 11, column = 0)







root.mainloop()
